# %%
import pandas as pd 
df = pd.read_csv(r'Data_Marketing_Customer_Analysis_Round3.csv')

# %%
import numpy as np

numerical = df.select_dtypes(include=np.number)
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
categoricals = df.select_dtypes(include=np.object)
categoricals
# Out:
# /var/folders/n_/mqs2n84x0k3g_vz_3dbgh2yr0000gp/T/ipykernel_38930/1372396761.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categoricals = df.select_dtypes(include=np.object)
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# ...

# %%
import seaborn as sns
sns.scatterplot(data=numerical, x="customer_lifetime_value", y="total_claim_amount")
# Out:
# <AxesSubplot:xlabel='customer_lifetime_value', ylabel='total_claim_amount'>

# %%
import seaborn as sns
sns.scatterplot(data=numerical, x="income", y="total_claim_amount")
# Out:
# <AxesSubplot:xlabel='income', ylabel='total_claim_amount'>

# %%
import seaborn as sns
sns.scatterplot(data=numerical, x="monthly_premium_auto", y="total_claim_amount")
# Out:
# <AxesSubplot:xlabel='monthly_premium_auto', ylabel='total_claim_amount'>

# %%
sns.scatterplot(data=numerical, x="months_since_last_claim", y="total_claim_amount")
# Out:
# <AxesSubplot:xlabel='months_since_last_claim', ylabel='total_claim_amount'>

# %%
import matplotlib.pyplot as ptl
numerical.hist('income')
# Out:
# array([[<AxesSubplot:title={'center':'income'}>]], dtype=object)

# %%
numerical.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.003732
# income                                        0.003732  1.000000
# monthly_premium_auto                          0.404235 -0.002431
# months_since_last_claim                       0.011912 -0.026564
# months_since_policy_inception                 0.017055  0.003846
# number_of_open_complaints                    -0.032371  0.018903
# number_of_policies                            0.016789 -0.004461
# total_claim_amount                            0.232849 -0.111221
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.404235                 0.011912
# income                                    -0.002431                -0.026564
# monthly_premium_auto                       1.000000                 0.010036
# ...

# %%
sns.heatmap(numerical.corr());
